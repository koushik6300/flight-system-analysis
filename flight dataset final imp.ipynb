# %%
import pandas as pd

# %%
df=pd.read_excel("D:\\Flight dataset\\Data_Train.xlsx")

# %%
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
df['Airline'].unique()
# Out:
# array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)

# %%
df['Airline']=df['Airline'].map({'IndiGo':0, 'Air India':1, 'Jet Airways':2, 'SpiceJet':3,
       'Multiple carriers':4, 'GoAir':5, 'Vistara':6, 'Air Asia':7,
       'Vistara Premium economy':8, 'Jet Airways Business':9,
       'Multiple carriers Premium economy':10, 'Trujet':11})

# %%
df.head()
# Out:
#    Airline Date_of_Journey    Source Destination                  Route  \
# 0        0      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1        1       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2        2       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3        0      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4        0      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df['Source'].unique()
# Out:
# array(['Banglore', 'Kolkata', 'Delhi', 'Chennai', 'Mumbai'], dtype=object)

# %%
df['Source']=df['Source'].map({'Banglore':0, 'Kolkata':1, 'Delhi':2, 'Chennai':3, 'Mumbai':4})

# %%
df.head()
# Out:
#    Airline Date_of_Journey  Source Destination                  Route  \
# 0        0      24/03/2019       0   New Delhi              BLR → DEL
# 1        1       1/05/2019       1    Banglore  CCU → IXR → BBI → BLR
# 2        2       9/06/2019       2      Cochin  DEL → LKO → BOM → COK
# 3        0      12/05/2019       1    Banglore        CCU → NAG → BLR
# 4        0      01/03/2019       0   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df['Destination'].unique()
# Out:
# array(['New Delhi', 'Banglore', 'Cochin', 'Kolkata', 'Delhi', 'Hyderabad'],
#       dtype=object)

# %%
df['Destination']=df['Destination'].map({'New Delhi':0, 'Banglore':1, 'Cochin':2, 'Kolkata':3, 'Delhi':4, 'Hyderabad':5})

# %%
df.head()
# Out:
#    Airline Date_of_Journey  Source  Destination                  Route  \
# 0        0      24/03/2019       0            0              BLR → DEL
# 1        1       1/05/2019       1            1  CCU → IXR → BBI → BLR
# 2        2       9/06/2019       2            2  DEL → LKO → BOM → COK
# 3        0      12/05/2019       1            1        CCU → NAG → BLR
# 4        0      01/03/2019       0            0        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', nan, '4 stops'],
#       dtype=object)

# %%
df['Total_Stops']=df['Total_Stops'].map({'non-stop':0, '2 stops':1, '1 stop':2, '3 stops':3,'4 stops':5})

# %%
df.head()
# Out:
#    Airline Date_of_Journey  Source  Destination                  Route  \
# 0        0      24/03/2019       0            0              BLR → DEL
# 1        1       1/05/2019       1            1  CCU → IXR → BBI → BLR
# 2        2       9/06/2019       2            2  DEL → LKO → BOM → COK
# 3        0      12/05/2019       1            1        CCU → NAG → BLR
# 4        0      01/03/2019       0            0        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration  Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m          0.0         No info   3897
# 1    05:50         13:15   7h 25m          1.0         No info   7662
# 2    09:25  04:25 10 Jun      19h          1.0         No info  13882
# 3    18:05         23:30   5h 25m          2.0         No info   6218
# 4    16:50         21:35   4h 45m          2.0         No info  13302

# %%
df['Additional_Info'].unique()
# Out:
# array(['No info', 'In-flight meal not included',
#        'No check-in baggage included', '1 Short layover', 'No Info',
#        '1 Long layover', 'Change airports', 'Business class',
#        'Red-eye flight', '2 Long layover'], dtype=object)

# %%
df['Additional_Info']=df['Additional_Info'].map({'No info':0, 'In-flight meal not included':1,
       'No check-in baggage included':2, '1 Short layover':3, 'No Info':4,
       '1 Long layover':5, 'Change airports':6, 'Business class':7,
       'Red-eye flight':8, '2 Long layover':9})

# %%
df.head()
# Out:
#    Airline Date_of_Journey  Source  Destination                  Route  \
# 0        0      24/03/2019       0            0              BLR → DEL
# 1        1       1/05/2019       1            1  CCU → IXR → BBI → BLR
# 2        2       9/06/2019       2            2  DEL → LKO → BOM → COK
# 3        0      12/05/2019       1            1        CCU → NAG → BLR
# 4        0      01/03/2019       0            0        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration  Total_Stops  Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m          0.0                0   3897
# 1    05:50         13:15   7h 25m          1.0                0   7662
# 2    09:25  04:25 10 Jun      19h          1.0                0  13882
# 3    18:05         23:30   5h 25m          2.0                0   6218
# 4    16:50         21:35   4h 45m          2.0                0  13302

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  int64
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  int64
#  3   Destination      10683 non-null  int64
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  float64
#  9   Additional_Info  10683 non-null  int64
#  10  Price            10683 non-null  int64
# dtypes: float64(1), int64(5), object(5)
# memory usage: 918.2+ KB

# %%
df.drop(['Route'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Airline Date_of_Journey  Source  Destination Dep_Time  Arrival_Time  \
# 0        0      24/03/2019       0            0    22:20  01:10 22 Mar
# 1        1       1/05/2019       1            1    05:50         13:15
# 2        2       9/06/2019       2            2    09:25  04:25 10 Jun
# 3        0      12/05/2019       1            1    18:05         23:30
# 4        0      01/03/2019       0            0    16:50         21:35
#
#   Duration  Total_Stops  Additional_Info  Price
# 0   2h 50m          0.0                0   3897
# 1   7h 25m          1.0                0   7662
# 2      19h          1.0                0  13882
# 3   5h 25m          2.0                0   6218
# 4   4h 45m          2.0                0  13302

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  int64
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  int64
#  3   Destination      10683 non-null  int64
#  4   Dep_Time         10683 non-null  object
#  5   Arrival_Time     10683 non-null  object
#  6   Duration         10683 non-null  object
#  7   Total_Stops      10682 non-null  float64
#  8   Additional_Info  10683 non-null  int64
#  9   Price            10683 non-null  int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 834.7+ KB

# %%
df.head()
# Out:
#    Airline Date_of_Journey  Source  Destination Dep_Time  Arrival_Time  \
# 0        0      24/03/2019       0            0    22:20  01:10 22 Mar
# 1        1       1/05/2019       1            1    05:50         13:15
# 2        2       9/06/2019       2            2    09:25  04:25 10 Jun
# 3        0      12/05/2019       1            1    18:05         23:30
# 4        0      01/03/2019       0            0    16:50         21:35
#
#   Duration  Total_Stops  Additional_Info  Price
# 0   2h 50m          0.0                0   3897
# 1   7h 25m          1.0                0   7662
# 2      19h          1.0                0  13882
# 3   5h 25m          2.0                0   6218
# 4   4h 45m          2.0                0  13302

# %%
df['dep_hour']=df['Dep_Time'].str.split(':').str[0]

# %%
df
# Out:
#        Airline Date_of_Journey  Source  Destination Dep_Time  Arrival_Time  \
# 0            0      24/03/2019       0            0    22:20  01:10 22 Mar
# 1            1       1/05/2019       1            1    05:50         13:15
# 2            2       9/06/2019       2            2    09:25  04:25 10 Jun
# 3            0      12/05/2019       1            1    18:05         23:30
# 4            0      01/03/2019       0            0    16:50         21:35
# ...        ...             ...     ...          ...      ...           ...
# 10678        7       9/04/2019       1            1    19:55         22:25
# 10679        1      27/04/2019       1            1    20:45         23:20
# 10680        2      27/04/2019       0            4    08:20         11:20
# 10681        6      01/03/2019       0            0    11:30         14:10
# 10682        1       9/05/2019       2            2    10:55         19:15
#
#       Duration  Total_Stops  Additional_Info  Price dep_hour
# ...

# %%
df['dep_min']=df['Dep_Time'].str.split(':').str[1]

# %%
df.head()
# Out:
#    Airline Date_of_Journey  Source  Destination Dep_Time  Arrival_Time  \
# 0        0      24/03/2019       0            0    22:20  01:10 22 Mar
# 1        1       1/05/2019       1            1    05:50         13:15
# 2        2       9/06/2019       2            2    09:25  04:25 10 Jun
# 3        0      12/05/2019       1            1    18:05         23:30
# 4        0      01/03/2019       0            0    16:50         21:35
#
#   Duration  Total_Stops  Additional_Info  Price dep_hour dep_min
# 0   2h 50m          0.0                0   3897       22      20
# 1   7h 25m          1.0                0   7662       05      50
# 2      19h          1.0                0  13882       09      25
# 3   5h 25m          2.0                0   6218       18      05
# 4   4h 45m          2.0                0  13302       16      50

# %%
df.drop(['Dep_Time'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Airline Date_of_Journey  Source  Destination  Arrival_Time Duration  \
# 0        0      24/03/2019       0            0  01:10 22 Mar   2h 50m
# 1        1       1/05/2019       1            1         13:15   7h 25m
# 2        2       9/06/2019       2            2  04:25 10 Jun      19h
# 3        0      12/05/2019       1            1         23:30   5h 25m
# 4        0      01/03/2019       0            0         21:35   4h 45m
#
#    Total_Stops  Additional_Info  Price dep_hour dep_min
# 0          0.0                0   3897       22      20
# 1          1.0                0   7662       05      50
# 2          1.0                0  13882       09      25
# 3          2.0                0   6218       18      05
# 4          2.0                0  13302       16      50

# %%
df['date']=df['Date_of_Journey'].str.split('/').str[0]

# %%
df.head()
# Out:
#    Airline Date_of_Journey  Source  Destination  Arrival_Time Duration  \
# 0        0      24/03/2019       0            0  01:10 22 Mar   2h 50m
# 1        1       1/05/2019       1            1         13:15   7h 25m
# 2        2       9/06/2019       2            2  04:25 10 Jun      19h
# 3        0      12/05/2019       1            1         23:30   5h 25m
# 4        0      01/03/2019       0            0         21:35   4h 45m
#
#    Total_Stops  Additional_Info  Price dep_hour dep_min date
# 0          0.0                0   3897       22      20   24
# 1          1.0                0   7662       05      50    1
# 2          1.0                0  13882       09      25    9
# 3          2.0                0   6218       18      05   12
# 4          2.0                0  13302       16      50   01

# %%
df['month']=df['Date_of_Journey'].str.split('/').str[1]

# %%
df.head()
# Out:
#    Airline Date_of_Journey  Source  Destination  Arrival_Time Duration  \
# 0        0      24/03/2019       0            0  01:10 22 Mar   2h 50m
# 1        1       1/05/2019       1            1         13:15   7h 25m
# 2        2       9/06/2019       2            2  04:25 10 Jun      19h
# 3        0      12/05/2019       1            1         23:30   5h 25m
# 4        0      01/03/2019       0            0         21:35   4h 45m
#
#    Total_Stops  Additional_Info  Price dep_hour dep_min date month
# 0          0.0                0   3897       22      20   24    03
# 1          1.0                0   7662       05      50    1    05
# 2          1.0                0  13882       09      25    9    06
# 3          2.0                0   6218       18      05   12    05
# 4          2.0                0  13302       16      50   01    03

# %%
df['year']=df['Date_of_Journey'].str.split('/').str[2]

# %%
df.head()
# Out:
#    Airline Date_of_Journey  Source  Destination  Arrival_Time Duration  \
# 0        0      24/03/2019       0            0  01:10 22 Mar   2h 50m
# 1        1       1/05/2019       1            1         13:15   7h 25m
# 2        2       9/06/2019       2            2  04:25 10 Jun      19h
# 3        0      12/05/2019       1            1         23:30   5h 25m
# 4        0      01/03/2019       0            0         21:35   4h 45m
#
#    Total_Stops  Additional_Info  Price dep_hour dep_min date month  year
# 0          0.0                0   3897       22      20   24    03  2019
# 1          1.0                0   7662       05      50    1    05  2019
# 2          1.0                0  13882       09      25    9    06  2019
# 3          2.0                0   6218       18      05   12    05  2019
# 4          2.0                0  13302       16      50   01    03  2019

# %%
df.drop(['Date_of_Journey'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Airline  Source  Destination  Arrival_Time Duration  Total_Stops  \
# 0        0       0            0  01:10 22 Mar   2h 50m          0.0
# 1        1       1            1         13:15   7h 25m          1.0
# 2        2       2            2  04:25 10 Jun      19h          1.0
# 3        0       1            1         23:30   5h 25m          2.0
# 4        0       0            0         21:35   4h 45m          2.0
#
#    Additional_Info  Price dep_hour dep_min date month  year
# 0                0   3897       22      20   24    03  2019
# 1                0   7662       05      50    1    05  2019
# 2                0  13882       09      25    9    06  2019
# 3                0   6218       18      05   12    05  2019
# 4                0  13302       16      50   01    03  2019

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  int64
#  1   Source           10683 non-null  int64
#  2   Destination      10683 non-null  int64
#  3   Arrival_Time     10683 non-null  object
#  4   Duration         10683 non-null  object
#  5   Total_Stops      10682 non-null  float64
#  6   Additional_Info  10683 non-null  int64
#  7   Price            10683 non-null  int64
#  8   dep_hour         10683 non-null  object
#  9   dep_min          10683 non-null  object
#  10  date             10683 non-null  object
#  11  month            10683 non-null  object
#  12  year             10683 non-null  object
# dtypes: float64(1), int64(5), object(7)
# memory usage: 1.1+ MB

# %%
df.columns
# Out:
# Index(['Airline', 'Source', 'Destination', 'Arrival_Time', 'Duration',
#        'Total_Stops', 'Additional_Info', 'Price', 'dep_hour', 'dep_min',
#        'date', 'month', 'year'],
#       dtype='object')

# %%
df['dep_hour']=df['dep_hour'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  int64
#  1   Source           10683 non-null  int64
#  2   Destination      10683 non-null  int64
#  3   Arrival_Time     10683 non-null  object
#  4   Duration         10683 non-null  object
#  5   Total_Stops      10682 non-null  float64
#  6   Additional_Info  10683 non-null  int64
#  7   Price            10683 non-null  int64
#  8   dep_hour         10683 non-null  int32
#  9   dep_min          10683 non-null  object
#  10  date             10683 non-null  object
#  11  month            10683 non-null  object
#  12  year             10683 non-null  object
# dtypes: float64(1), int32(1), int64(5), object(6)
# memory usage: 1.0+ MB

# %%
df['dep_min']=df['dep_min'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  int64
#  1   Source           10683 non-null  int64
#  2   Destination      10683 non-null  int64
#  3   Arrival_Time     10683 non-null  object
#  4   Duration         10683 non-null  object
#  5   Total_Stops      10682 non-null  float64
#  6   Additional_Info  10683 non-null  int64
#  7   Price            10683 non-null  int64
#  8   dep_hour         10683 non-null  int32
#  9   dep_min          10683 non-null  int32
#  10  date             10683 non-null  object
#  11  month            10683 non-null  object
#  12  year             10683 non-null  object
# dtypes: float64(1), int32(2), int64(5), object(5)
# memory usage: 1001.7+ KB

# %%
df['date']=df['date'].astype(int)

# %%
df['month']=df['month'].astype(int)

# %%
df['year']=df['year'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  int64
#  1   Source           10683 non-null  int64
#  2   Destination      10683 non-null  int64
#  3   Arrival_Time     10683 non-null  object
#  4   Duration         10683 non-null  object
#  5   Total_Stops      10682 non-null  float64
#  6   Additional_Info  10683 non-null  int64
#  7   Price            10683 non-null  int64
#  8   dep_hour         10683 non-null  int32
#  9   dep_min          10683 non-null  int32
#  10  date             10683 non-null  int32
#  11  month            10683 non-null  int32
#  12  year             10683 non-null  int32
# dtypes: float64(1), int32(5), int64(5), object(2)
# memory usage: 876.5+ KB

# %%
df.head()
# Out:
#    Airline  Source  Destination  Arrival_Time Duration  Total_Stops  \
# 0        0       0            0  01:10 22 Mar   2h 50m          0.0
# 1        1       1            1         13:15   7h 25m          1.0
# 2        2       2            2  04:25 10 Jun      19h          1.0
# 3        0       1            1         23:30   5h 25m          2.0
# 4        0       0            0         21:35   4h 45m          2.0
#
#    Additional_Info  Price  dep_hour  dep_min  date  month  year
# 0                0   3897        22       20    24      3  2019
# 1                0   7662         5       50     1      5  2019
# 2                0  13882         9       25     9      6  2019
# 3                0   6218        18        5    12      5  2019
# 4                0  13302        16       50     1      3  2019

# %%
df['Duration_hr']=df['Duration'].str.split('h').str[0]

# %%
df
# Out:
#        Airline  Source  Destination  Arrival_Time Duration  Total_Stops  \
# 0            0       0            0  01:10 22 Mar   2h 50m          0.0
# 1            1       1            1         13:15   7h 25m          1.0
# 2            2       2            2  04:25 10 Jun      19h          1.0
# 3            0       1            1         23:30   5h 25m          2.0
# 4            0       0            0         21:35   4h 45m          2.0
# ...        ...     ...          ...           ...      ...          ...
# 10678        7       1            1         22:25   2h 30m          0.0
# 10679        1       1            1         23:20   2h 35m          0.0
# 10680        2       0            4         11:20       3h          0.0
# 10681        6       0            0         14:10   2h 40m          0.0
# 10682        1       2            2         19:15   8h 20m          1.0
#
#        Additional_Info  Price  dep_hour  dep_min  date  month  year  \
# ...

# %%
df['Duration_min']=df['Duration'].str.split('h').str[1]

# %%
df
# Out:
#        Airline  Source  Destination  Arrival_Time Duration  Total_Stops  \
# 0            0       0            0  01:10 22 Mar   2h 50m          0.0
# 1            1       1            1         13:15   7h 25m          1.0
# 2            2       2            2  04:25 10 Jun      19h          1.0
# 3            0       1            1         23:30   5h 25m          2.0
# 4            0       0            0         21:35   4h 45m          2.0
# ...        ...     ...          ...           ...      ...          ...
# 10678        7       1            1         22:25   2h 30m          0.0
# 10679        1       1            1         23:20   2h 35m          0.0
# 10680        2       0            4         11:20       3h          0.0
# 10681        6       0            0         14:10   2h 40m          0.0
# 10682        1       2            2         19:15   8h 20m          1.0
#
#        Additional_Info  Price  dep_hour  dep_min  date  month  year  \
# ...

# %%
df['Duration_min']=df['Duration_min'].str.split('m').str[0]

# %%
df.drop(['Duration'],axis=1,inplace=True)

# %%
df
# Out:
#        Airline  Source  Destination  Arrival_Time  Total_Stops  \
# 0            0       0            0  01:10 22 Mar          0.0
# 1            1       1            1         13:15          1.0
# 2            2       2            2  04:25 10 Jun          1.0
# 3            0       1            1         23:30          2.0
# 4            0       0            0         21:35          2.0
# ...        ...     ...          ...           ...          ...
# 10678        7       1            1         22:25          0.0
# 10679        1       1            1         23:20          0.0
# 10680        2       0            4         11:20          0.0
# 10681        6       0            0         14:10          0.0
# 10682        1       2            2         19:15          1.0
#
#        Additional_Info  Price  dep_hour  dep_min  date  month  year  \
# 0                    0   3897        22       20    24      3  2019
# 1                    0   7662         5       50     1      5  2019
# ...

# %%
df['Arrival_Time'].unique()
# Out:
# array(['01:10 22 Mar', '13:15', '04:25 10 Jun', ..., '06:50 10 Mar',
#        '00:05 19 Mar', '21:20 13 Mar'], dtype=object)

# %%
df['Arrival_Time_time']=df['Arrival_Time'].str.split(' ').str[0]

# %%
df
# Out:
#        Airline  Source  Destination  Arrival_Time  Total_Stops  \
# 0            0       0            0  01:10 22 Mar          0.0
# 1            1       1            1         13:15          1.0
# 2            2       2            2  04:25 10 Jun          1.0
# 3            0       1            1         23:30          2.0
# 4            0       0            0         21:35          2.0
# ...        ...     ...          ...           ...          ...
# 10678        7       1            1         22:25          0.0
# 10679        1       1            1         23:20          0.0
# 10680        2       0            4         11:20          0.0
# 10681        6       0            0         14:10          0.0
# 10682        1       2            2         19:15          1.0
#
#        Additional_Info  Price  dep_hour  dep_min  date  month  year  \
# 0                    0   3897        22       20    24      3  2019
# 1                    0   7662         5       50     1      5  2019
# ...

# %%
df['Arrival_Time_date']=df['Arrival_Time'].str.split(' ').str[1]

# %%
df
# Out:
#        Airline  Source  Destination  Arrival_Time  Total_Stops  \
# 0            0       0            0  01:10 22 Mar          0.0
# 1            1       1            1         13:15          1.0
# 2            2       2            2  04:25 10 Jun          1.0
# 3            0       1            1         23:30          2.0
# 4            0       0            0         21:35          2.0
# ...        ...     ...          ...           ...          ...
# 10678        7       1            1         22:25          0.0
# 10679        1       1            1         23:20          0.0
# 10680        2       0            4         11:20          0.0
# 10681        6       0            0         14:10          0.0
# 10682        1       2            2         19:15          1.0
#
#        Additional_Info  Price  dep_hour  dep_min  date  month  year  \
# 0                    0   3897        22       20    24      3  2019
# 1                    0   7662         5       50     1      5  2019
# ...

# %%
df['Arrival_Time_momth']=df['Arrival_Time'].str.split(' ').str[2]

# %%
df
# Out:
#        Airline  Source  Destination  Arrival_Time  Total_Stops  \
# 0            0       0            0  01:10 22 Mar          0.0
# 1            1       1            1         13:15          1.0
# 2            2       2            2  04:25 10 Jun          1.0
# 3            0       1            1         23:30          2.0
# 4            0       0            0         21:35          2.0
# ...        ...     ...          ...           ...          ...
# 10678        7       1            1         22:25          0.0
# 10679        1       1            1         23:20          0.0
# 10680        2       0            4         11:20          0.0
# 10681        6       0            0         14:10          0.0
# 10682        1       2            2         19:15          1.0
#
#        Additional_Info  Price  dep_hour  dep_min  date  month  year  \
# 0                    0   3897        22       20    24      3  2019
# 1                    0   7662         5       50     1      5  2019
# ...

# %%
df.drop(['Arrival_Time'],axis=1,inplace=True)

# %%
df
# Out:
#        Airline  Source  Destination  Total_Stops  Additional_Info  Price  \
# 0            0       0            0          0.0                0   3897
# 1            1       1            1          1.0                0   7662
# 2            2       2            2          1.0                0  13882
# 3            0       1            1          2.0                0   6218
# 4            0       0            0          2.0                0  13302
# ...        ...     ...          ...          ...              ...    ...
# 10678        7       1            1          0.0                0   4107
# 10679        1       1            1          0.0                0   4145
# 10680        2       0            4          0.0                0   7229
# 10681        6       0            0          0.0                0  12648
# 10682        1       2            2          1.0                0  11753
#
#        dep_hour  dep_min  date  month  year Duration_hr Duration_min  \
# ...

# %%
df.columns
# Out:
# Index(['Airline', 'Source', 'Destination', 'Total_Stops', 'Additional_Info',
#        'Price', 'dep_hour', 'dep_min', 'date', 'month', 'year', 'Duration_hr',
#        'Duration_min', 'Arrival_Time_time', 'Arrival_Time_date',
#        'Arrival_Time_momth'],
#       dtype='object')

# %%
df.drop(['Arrival_Time_date','Arrival_Time_momth'],axis=1,inplace=True)

# %%
df
# Out:
#        Airline  Source  Destination  Total_Stops  Additional_Info  Price  \
# 0            0       0            0          0.0                0   3897
# 1            1       1            1          1.0                0   7662
# 2            2       2            2          1.0                0  13882
# 3            0       1            1          2.0                0   6218
# 4            0       0            0          2.0                0  13302
# ...        ...     ...          ...          ...              ...    ...
# 10678        7       1            1          0.0                0   4107
# 10679        1       1            1          0.0                0   4145
# 10680        2       0            4          0.0                0   7229
# 10681        6       0            0          0.0                0  12648
# 10682        1       2            2          1.0                0  11753
#
#        dep_hour  dep_min  date  month  year Duration_hr Duration_min  \
# ...

# %%
df['Arrival_Time_hr']=df['Arrival_Time_time'].str.split(':').str[0]
df['Arrival_Time_min']=df['Arrival_Time_time'].str.split(':').str[1]

# %%
df
# Out:
#        Airline  Source  Destination  Total_Stops  Additional_Info  Price  \
# 0            0       0            0          0.0                0   3897
# 1            1       1            1          1.0                0   7662
# 2            2       2            2          1.0                0  13882
# 3            0       1            1          2.0                0   6218
# 4            0       0            0          2.0                0  13302
# ...        ...     ...          ...          ...              ...    ...
# 10678        7       1            1          0.0                0   4107
# 10679        1       1            1          0.0                0   4145
# 10680        2       0            4          0.0                0   7229
# 10681        6       0            0          0.0                0  12648
# 10682        1       2            2          1.0                0  11753
#
#        dep_hour  dep_min  date  month  year Duration_hr Duration_min  \
# ...

# %%
df.drop(['Arrival_Time_time'],axis=1,inplace=True)

# %%
df
# Out:
#        Airline  Source  Destination  Total_Stops  Additional_Info  Price  \
# 0            0       0            0          0.0                0   3897
# 1            1       1            1          1.0                0   7662
# 2            2       2            2          1.0                0  13882
# 3            0       1            1          2.0                0   6218
# 4            0       0            0          2.0                0  13302
# ...        ...     ...          ...          ...              ...    ...
# 10678        7       1            1          0.0                0   4107
# 10679        1       1            1          0.0                0   4145
# 10680        2       0            4          0.0                0   7229
# 10681        6       0            0          0.0                0  12648
# 10682        1       2            2          1.0                0  11753
#
#        dep_hour  dep_min  date  month  year Duration_hr Duration_min  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Airline           10683 non-null  int64
#  1   Source            10683 non-null  int64
#  2   Destination       10683 non-null  int64
#  3   Total_Stops       10682 non-null  float64
#  4   Additional_Info   10683 non-null  int64
#  5   Price             10683 non-null  int64
#  6   dep_hour          10683 non-null  int32
#  7   dep_min           10683 non-null  int32
#  8   date              10683 non-null  int32
#  9   month             10683 non-null  int32
#  10  year              10683 non-null  int32
#  11  Duration_hr       10683 non-null  object
#  12  Duration_min      10682 non-null  object
#  13  Arrival_Time_hr   10683 non-null  object
#  14  Arrival_Time_min  10683 non-null  object
# dtypes: float64(1), int32(5), int64(5), object(4)
# memory usage: 1.0+ MB

# %%
df['Duration_hr'].unique()
# Out:
# array(['2', '7', '19', '5', '4', '15', '21', '25', '13', '12', '26', '22',
#        '23', '20', '10', '6', '11', '8', '16', '3', '27', '1', '14', '9',
#        '18', '17', '24', '30', '28', '29', '37', '34', '38', '35', '36',
#        '47', '33', '32', '31', '42', '39', '5m', '41', '40'], dtype=object)

# %%
df['Duration_hr']=df['Duration_hr'].str.split('m').str[0]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Airline           10683 non-null  int64
#  1   Source            10683 non-null  int64
#  2   Destination       10683 non-null  int64
#  3   Total_Stops       10682 non-null  float64
#  4   Additional_Info   10683 non-null  int64
#  5   Price             10683 non-null  int64
#  6   dep_hour          10683 non-null  int32
#  7   dep_min           10683 non-null  int32
#  8   date              10683 non-null  int32
#  9   month             10683 non-null  int32
#  10  year              10683 non-null  int32
#  11  Duration_hr       10683 non-null  object
#  12  Duration_min      10682 non-null  object
#  13  Arrival_Time_hr   10683 non-null  object
#  14  Arrival_Time_min  10683 non-null  object
# dtypes: float64(1), int32(5), int64(5), object(4)
# memory usage: 1.0+ MB

# %%
df['Duration_hr']=df['Duration_hr'].astype(int)

# %%
df.head()
# Out:
#    Airline  Source  Destination  Total_Stops  Additional_Info  Price  \
# 0        0       0            0          0.0                0   3897
# 1        1       1            1          1.0                0   7662
# 2        2       2            2          1.0                0  13882
# 3        0       1            1          2.0                0   6218
# 4        0       0            0          2.0                0  13302
#
#    dep_hour  dep_min  date  month  year  Duration_hr Duration_min  \
# 0        22       20    24      3  2019            2           50
# 1         5       50     1      5  2019            7           25
# 2         9       25     9      6  2019           19
# 3        18        5    12      5  2019            5           25
# 4        16       50     1      3  2019            4           45
#
#   Arrival_Time_hr Arrival_Time_min
# 0              01               10
# 1              13               15
# 2              04               25
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Airline           10683 non-null  int64
#  1   Source            10683 non-null  int64
#  2   Destination       10683 non-null  int64
#  3   Total_Stops       10682 non-null  float64
#  4   Additional_Info   10683 non-null  int64
#  5   Price             10683 non-null  int64
#  6   dep_hour          10683 non-null  int32
#  7   dep_min           10683 non-null  int32
#  8   date              10683 non-null  int32
#  9   month             10683 non-null  int32
#  10  year              10683 non-null  int32
#  11  Duration_hr       10683 non-null  int32
#  12  Duration_min      10682 non-null  object
#  13  Arrival_Time_hr   10683 non-null  object
#  14  Arrival_Time_min  10683 non-null  object
# dtypes: float64(1), int32(6), int64(5), object(3)
# memory usage: 1001.7+ KB

# %%
df['Duration_min'].unique()
# Out:
# array([' 50', ' 25', '', ' 45', ' 30', ' 5', ' 15', ' 35', ' 10', ' 20',
#        ' 55', ' 40', nan], dtype=object)

# %%
df['Duration_min']=df['Duration_min'].map({'nan':0})

# %%
df.head()
# Out:
#    Airline  Source  Destination  Total_Stops  Additional_Info  Price  \
# 0        0       0            0          0.0                0   3897
# 1        1       1            1          1.0                0   7662
# 2        2       2            2          1.0                0  13882
# 3        0       1            1          2.0                0   6218
# 4        0       0            0          2.0                0  13302
#
#    dep_hour  dep_min  date  month  year  Duration_hr  Duration_min  \
# 0        22       20    24      3  2019            2           NaN
# 1         5       50     1      5  2019            7           NaN
# 2         9       25     9      6  2019           19           NaN
# 3        18        5    12      5  2019            5           NaN
# 4        16       50     1      3  2019            4           NaN
#
#   Arrival_Time_hr Arrival_Time_min
# 0              01               10
# 1              13               15
# 2              04               25
# ...

# %%
df['Duration_min']=df['Duration_min'].fillna(0)

# %%
df
# Out:
#        Airline  Source  Destination  Total_Stops  Additional_Info  Price  \
# 0            0       0            0          0.0                0   3897
# 1            1       1            1          1.0                0   7662
# 2            2       2            2          1.0                0  13882
# 3            0       1            1          2.0                0   6218
# 4            0       0            0          2.0                0  13302
# ...        ...     ...          ...          ...              ...    ...
# 10678        7       1            1          0.0                0   4107
# 10679        1       1            1          0.0                0   4145
# 10680        2       0            4          0.0                0   7229
# 10681        6       0            0          0.0                0  12648
# 10682        1       2            2          1.0                0  11753
#
#        dep_hour  dep_min  date  month  year  Duration_hr  Duration_min  \
# ...

# %%
df['Duration_min']=df['Duration_min'].astype(int)

# %%
df['Arrival_Time_hr']=df['Arrival_Time_hr'].astype(int)

# %%
df['Arrival_Time_min']=df['Arrival_Time_min'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Airline           10683 non-null  int64
#  1   Source            10683 non-null  int64
#  2   Destination       10683 non-null  int64
#  3   Total_Stops       10682 non-null  float64
#  4   Additional_Info   10683 non-null  int64
#  5   Price             10683 non-null  int64
#  6   dep_hour          10683 non-null  int32
#  7   dep_min           10683 non-null  int32
#  8   date              10683 non-null  int32
#  9   month             10683 non-null  int32
#  10  year              10683 non-null  int32
#  11  Duration_hr       10683 non-null  int32
#  12  Duration_min      10683 non-null  int32
#  13  Arrival_Time_hr   10683 non-null  int32
#  14  Arrival_Time_min  10683 non-null  int32
# dtypes: float64(1), int32(9), int64(5)
# memory usage: 876.5 KB

# %%
df
# Out:
#        Airline  Source  Destination  Total_Stops  Additional_Info  Price  \
# 0            0       0            0          0.0                0   3897
# 1            1       1            1          1.0                0   7662
# 2            2       2            2          1.0                0  13882
# 3            0       1            1          2.0                0   6218
# 4            0       0            0          2.0                0  13302
# ...        ...     ...          ...          ...              ...    ...
# 10678        7       1            1          0.0                0   4107
# 10679        1       1            1          0.0                0   4145
# 10680        2       0            4          0.0                0   7229
# 10681        6       0            0          0.0                0  12648
# 10682        1       2            2          1.0                0  11753
#
#        dep_hour  dep_min  date  month  year  Duration_hr  Duration_min  \
# ...

# %%
import seaborn as sns

# %%
sns.barplot(x=df['Price'],y=df['year'])
# Out:
# <Axes: xlabel='Price', ylabel='year'>

# %%
df.isnull().sum()
# Out:
# Airline             0
# Source              0
# Destination         0
# Total_Stops         1
# Additional_Info     0
# Price               0
# dep_hour            0
# dep_min             0
# date                0
# month               0
# year                0
# Duration_hr         0
# Duration_min        0
# Arrival_Time_hr     0
# Arrival_Time_min    0
# dtype: int64

# %%
df['Total_Stops']=df['Total_Stops'].fillna(method='ffill')

# %%
df.isnull().sum()
# Out:
# Airline             0
# Source              0
# Destination         0
# Total_Stops         0
# Additional_Info     0
# Price               0
# dep_hour            0
# dep_min             0
# date                0
# month               0
# year                0
# Duration_hr         0
# Duration_min        0
# Arrival_Time_hr     0
# Arrival_Time_min    0
# dtype: int64

# %%
x=df.drop(['Price'],axis=1)

# %%
x
# Out:
#        Airline  Source  Destination  Total_Stops  Additional_Info  dep_hour  \
# 0            0       0            0          0.0                0        22
# 1            1       1            1          1.0                0         5
# 2            2       2            2          1.0                0         9
# 3            0       1            1          2.0                0        18
# 4            0       0            0          2.0                0        16
# ...        ...     ...          ...          ...              ...       ...
# 10678        7       1            1          0.0                0        19
# 10679        1       1            1          0.0                0        20
# 10680        2       0            4          0.0                0         8
# 10681        6       0            0          0.0                0        11
# 10682        1       2            2          1.0                0        10
#
# ...

# %%
y=df['Price']

# %%
 from sklearn.model_selection import train_test_split

# %%
 x_train, x_test, y_train, y_test = train_test_split( x, y, test_size=0.33, random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
z=RandomForestRegressor()

# %%
z.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred=z.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, y_pred)
# Out:
# 0.8762567275822931
